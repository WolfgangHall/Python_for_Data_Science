# %% [markdown]
# ETS Models (Error-Trend-Seasonality)
#     - exponential smoothing
#     - trend method models
#     - ETS decomposition

# %% [markdown]
# take the above terms for 'smoothing'
#     -> may add them, multiply them or just leave them out
#
# based off of these factors, you can try to create a model to fit the data

# %% [markdown]
# Time series decomposition with ETS
#
# - visualizing data based off ETS is a good way to build an understanding of its behavior

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
airline = pd.read_csv('airline_passengers.csv', index_col='Month')

# %%
airline.head()
# Out:
#          Thousands of Passengers
# Month
# 1949-01                    112.0
# 1949-02                    118.0
# 1949-03                    132.0
# 1949-04                    129.0
# 1949-05                    121.0

# %%
airline.plot()

# %%
airline.dropna(inplace=True)

# %%
airline.index = pd.to_datetime(airline.index)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(airline['Thousands of Passengers'], model='multiplicative')
# Out:
# C:\Users\johna\Anaconda3\lib\site-packages\statsmodels\tsa\filters\filtertools.py:28: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return np.r_[[np.nan] * head, x, [np.nan] * tail]

# %%
result.seasonal.plot()

# %%
result.trend.plot()

# %%
fig = result.plot()
